# %%
#--- ref: goo.gl/r3HQNE
#--- ref: Jupyter / IPython: After editing a module, changes are not effective without kernel restart
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import mfnn_factory as fac
import mfnn_graph as graph

#--- create data sets
training_data, validation_data, test_data = fac.create_np_data_sets()
inputs, targets = training_data
test_features, test_targets_z, datetimes, mean, std = test_data

#--- create neural network
mfnn = fac.create_mfnn(input_size=inputs.shape[2])
mfnn.summary()

#--- train the neural network
training_losses, validation_losses, accuracies = mfnn.fit(inputs, targets, 
                              learning_rate=0.25, epochs=600, batch_size=1024, 
                              validation_data=validation_data)
# Out:
# ---------------------------------------
# Neural network layers (inputs, outputs)
# ---------------------------------------
# Dense: (58, 64)
# Leaky ReLU: (64, 64)
# Dense: (64, 64)
# Leaky ReLU: (64, 64)
# Dense: (64, 64)
# Leaky ReLU: (64, 64)
# Dense: (64, 1)
# Leaky ReLU: (1, 1)
# ---------------------------------------
# Epoch 437 of 600 | Loss: 0.303642 | Validation Loss: 0.254098 | Accuracy: 0.419173
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-c6aa536dbd7f> in <module>()
#      14 training_losses, validation_losses, accuracies = mfnn.fit(inputs, targets,
#      15                               learning_rate=0.25, epochs=600, batch_size=1024,
# ---> 16                               validation_data=validation_data)
#      17
#      18 #--- TODO: implement a recitified linear unit for activation function of output
#
# C:\Users\Owner\Documents\git\mfnn\neural_network.py in fit(self, inputs, targets, epochs, learning_rate, batch_size, verbose, validation_data)
#     148             #--- 15nov17: we needed to select a random sample to prevent overfitting
#     149             batch_features, batch_labels = self.create_random_batch(inputs, targets, batch_size)
# --> 150             batch_loss     = self.train_on_batch(batch_features, batch_labels, learning_rate)
#     151
#     152             losses.append(batch_loss)
#
# C:\Users\Owner\Documents\git\mfnn\neural_network.py in train_on_batch(self, batch_features, batch_labels, learning_rate)
#     117         #--- process each row of features and labels in batch
#     118         for features, labels in zip(batch_features, batch_labels):
# --> 119             self.update_outputs(features)
#     120             self.update_errors(labels)
#     121
#
# C:\Users\Owner\Documents\git\mfnn\neural_network.py in update_outputs(self, inputs)
#      35         #--- one forward pass
#      36         #--- update first hidden layer [0]
# ---> 37         self.layers[0].update_outputs(inputs)
#      38
#      39         #--- update all remaining layers [1:]
#
# C:\Users\Owner\Documents\git\mfnn\layer.py in update_outputs(self, x)
#      78         # ... because it will be used to update delta_w in update_errors()
#      79         self.inputs = x
# ---> 80         self.outputs = np.dot(self.inputs, self.weights)
#      81         return
#      82
#
# KeyboardInterrupt:

# %%
#--- display the training loss over epoch
graph.plot_losses(training_losses, validation_losses)

# %%
#--- display accuracy
graph.plot_accuracies(accuracies)

# %%
#--- predict bike usage
predictions_z = mfnn.predict_on_batch(test_features)

#--- convert predictions from z_score to a raw value
predicted_values = predictions_z * std + mean
actual_values    = test_targets_z * std + mean

#--- plot the predictions against the actual values for a 24 hour period
graph.plot_predictions_24hr(predicted_values, actual_values, datetimes, "2012-12-20")

# %%
#--- display predicted vs actual usage for all data on a line chart
graph.plot_predictions(predicted_values, actual_values, datetimes)
